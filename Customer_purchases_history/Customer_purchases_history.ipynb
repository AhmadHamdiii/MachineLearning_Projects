# %% [markdown]
# In this checkpoint, we are going to work on 'Customer purchases history' dataset provided by Kaggle
#
# Dataset description: This dataset contains historical records for customer purchases from a supermarket X. The objective is to find the association rules to help supermarket owners find new marketing plans to improve their sales.
#
# ![Image](https://i.imgur.com/uYpSaHm_d.webp?maxwidth=780&fidelity=grand)
#
#
# toy_dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
#         ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
#         ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
#         ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
#         ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]
#
# 1. Run the apriori algorithm on the provided toy_dataset. Interpret the results.
# 2. Try to explore the checkpoint dataset using Pandas and Plotly.
# 3. Run the apriori algorithm on checkpoint dataset. Interpret the results and suggest a clear business plan to the supermarket owners based on your findings.

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
        ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
        ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
        ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
        ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]
dataset
# Out:
# [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
#  ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
#  ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
#  ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
#  ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)
df=pd.DataFrame(te_ary, columns=te.columns_)

# %%
df.head()
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.5)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
frequent_itemsets=apriori(df, min_support=0.5, use_colnames=True)
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0        0.75  0.9375     -0.04         0.8          -0.25
# 1        0.75  0.9375     -0.04         0.8          -0.25
# 2        0.75  1.2500      0.12         1.6           1.00
# 3        1.00  1.2500      0.12         inf           0.50

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets,metric="lift",min_threshold=0.75)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0        0.75  0.9375     -0.04         0.8          -0.25
# 1        0.75  0.9375     -0.04         0.8          -0.25
# 2        0.75  1.2500      0.12         1.6           1.00
# 3        1.00  1.2500      0.12         inf           0.50

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import os

# %%
data_path = r"C:\Users\Elle\Desktop\MACHINE LEARNING\MachineLearning_CheckPoints\Customer_purchases_history\Market_Basket_Optimisation.csv"

# %%
file_name = "Market_Basket_Optimisation.csv"
final_path = os.path.join (data_path , file_name)

# %%
df = pd.read_csv("Market_Basket_Optimisation.csv")

# %%
df.head()
# Out:
#    shrimp                 almonds                avocado                \
# 0  burgers                meatballs                               eggs
# 1                chutney                    NaN                    NaN
# 2  turkey                               avocado                    NaN
# 3  mineral water          milk                   energy bar
# 4         low fat yogurt                    NaN                    NaN
#
#    vegetables mix        green grapes          whole weat flour       \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3  whole wheat rice                  green tea                   NaN
# 4                    NaN                   NaN                   NaN
#
#   yams                  cottage cheese        energy drink           \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   tomato juice          low fat yogurt        green tea              \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   honey             salad                 mineral water          \
# 0               NaN                   NaN                   NaN
# 1               NaN                   NaN                   NaN
# 2               NaN                   NaN                   NaN
# 3               NaN                   NaN                   NaN
# 4               NaN                   NaN                   NaN
#
#   salmon             antioxydant juice  frozen smoothie  spinach      \
# 0                NaN                NaN              NaN         NaN
# 1                NaN                NaN              NaN         NaN
# 2                NaN                NaN              NaN         NaN
# 3                NaN                NaN              NaN         NaN
# 4                NaN                NaN              NaN         NaN
#
#    olive oil
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.tail()
# Out:
#       shrimp                 almonds                avocado                \
# 7495  butter                 light mayo                       fresh bread
# 7496  burgers                frozen vegetables      eggs
# 7497                chicken                    NaN                    NaN
# 7498  escalope                           green tea                    NaN
# 7499  eggs                   frozen smoothie        yogurt cake
#
#       vegetables mix         green grapes          whole weat flour       \
# 7495                    NaN                    NaN                   NaN
# 7496  french fries           magazines                         green tea
# 7497                    NaN                    NaN                   NaN
# 7498                    NaN                    NaN                   NaN
# 7499         low fat yogurt                    NaN                   NaN
#
#      yams                  cottage cheese        energy drink           \
# 7495                   NaN                   NaN                   NaN
# 7496                   NaN                   NaN                   NaN
# 7497                   NaN                   NaN                   NaN
# 7498                   NaN                   NaN                   NaN
# 7499                   NaN                   NaN                   NaN
#
#      tomato juice          low fat yogurt        green tea              \
# 7495                   NaN                   NaN                   NaN
# 7496                   NaN                   NaN                   NaN
# 7497                   NaN                   NaN                   NaN
# 7498                   NaN                   NaN                   NaN
# 7499                   NaN                   NaN                   NaN
#
#      honey             salad                 mineral water          \
# 7495               NaN                   NaN                   NaN
# 7496               NaN                   NaN                   NaN
# 7497               NaN                   NaN                   NaN
# 7498               NaN                   NaN                   NaN
# 7499               NaN                   NaN                   NaN
#
#      salmon             antioxydant juice  frozen smoothie  spinach      \
# 7495                NaN                NaN              NaN         NaN
# 7496                NaN                NaN              NaN         NaN
# 7497                NaN                NaN              NaN         NaN
# 7498                NaN                NaN              NaN         NaN
# 7499                NaN                NaN              NaN         NaN
#
#       olive oil
# 7495        NaN
# 7496        NaN
# 7497        NaN
# 7498        NaN
# 7499        NaN

# %%
df= [[y for y in x if pd.notna(y)] for x in df.values.tolist()]

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(df).transform(df)   
df=pd.DataFrame(te_ary, columns=te.columns_)  
df
# Out:
#       almonds  almonds                antioxydant juice  antioxydant juice   \
# 0       False                  False              False               False
# 1       False                  False              False               False
# 2       False                  False              False               False
# 3       False                  False              False               False
# 4       False                  False              False               False
# ...       ...                    ...                ...                 ...
# 7495    False                  False              False               False
# 7496    False                  False              False               False
# 7497    False                  False              False               False
# 7498    False                  False              False               False
# 7499    False                  False              False               False
#
#       antioxydant juice      asparagus  asparagus              avocado  \
# 0                     False      False                  False    False
# 1                     False      False                  False    False
# 2                     False      False                  False     True
# 3                     False      False                  False    False
# 4                     False      False                  False    False
# ...                     ...        ...                    ...      ...
# 7495                  False      False                  False    False
# 7496                  False      False                  False    False
# 7497                  False      False                  False    False
# 7498                  False      False                  False    False
# 7499                  False      False                  False    False
#
#       avocado                babies food  ...  whole wheat pasta      \
# 0                     False        False  ...                  False
# 1                     False        False  ...                  False
# 2                     False        False  ...                  False
# 3                     False        False  ...                  False
# 4                     False        False  ...                  False
# ...                     ...          ...  ...                    ...
# 7495                  False        False  ...                  False
# 7496                  False        False  ...                  False
# 7497                  False        False  ...                  False
# 7498                  False        False  ...                  False
# 7499                  False        False  ...                  False
#
#       whole wheat rice  whole wheat rice        yams  yams                   \
# 0                False                  False  False                  False
# 1                False                  False  False                  False
# 2                False                  False  False                  False
# 3                False                   True  False                  False
# 4                False                  False  False                  False
# ...                ...                    ...    ...                    ...
# 7495             False                  False  False                  False
# 7496             False                  False  False                  False
# 7497             False                  False  False                  False
# 7498             False                  False  False                  False
# 7499             False                  False  False                  False
#
#       yogurt cake  yogurt cake        yogurt cake            zucchini  \
# 0           False              False                  False     False
# 1           False              False                  False     False
# 2           False              False                  False     False
# 3           False              False                  False     False
# 4           False              False                  False     False
# ...           ...                ...                    ...       ...
# 7495        False              False                  False     False
# 7496        False              False                  False     False
# 7497        False              False                  False     False
# 7498        False              False                  False     False
# 7499        False              False                   True     False
#
#       zucchini
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 7495                  False
# 7496                  False
# 7497                  False
# 7498                  False
# 7499                  False
#
# [7500 rows x 275 columns]

# %%
frequent_itemsets=apriori(df, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
#     support                 itemsets
# 0  0.134133  (chocolate            )
# 1  0.139467  (eggs                 )
# 2  0.107200  (french fries         )
# 3  0.103733              (green tea)
# 4  0.116400  (milk                 )
# 5  0.216533  (mineral water        )
# 6  0.158667  (spaghetti            )

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.1)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets,metric="lift",min_threshold=0.1)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
